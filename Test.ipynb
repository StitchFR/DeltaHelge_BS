# %%
import numpy as np
import matplotlib.pyplot as plt
import Structure as Manager

# %%
Env = Manager.Environnement_Modelisation(T=1,
                                         Steps=365,
                                         Cout_Hedge=0.005,
                                         Periodicite_Hedge=2/365)

# %%
Option = Manager.BlackSchole_Modele(OptionType='Call',
                                    S0=100,
                                    K=100,
                                    T=1,
                                    sigma=0.2,
                                    r=0.05,
                                    q=0.05,
                                    round=3)

print(f"Option Price: {Option.Price} \n Delta: {Option.Delta}")
# Out:
# Option Price: 7.58
#  Delta: 0.51

# %%
Traj = Manager.Trajectoire(Env, Option,10)
plt.plot(Traj.Delta_Trajectoire[:,1])

# %%
Traj.DeltaHedge()
# Out:
# On hedge à cette période
# En période 0
#  delta option 0.514
#  quantité sous-jacent -0.514
#  valeur du portefeuille 43.56300000000001
#  delta portefeuille 0.0
# On ne hedge pas à cette période
# En période 1
#  delta option 0.54 | Var delta 0.026000000000000023
#  quantité sous-jacent -0.514 | Prix action 101.398
#  valeur du portefeuille 43.57142800000002
#  delta portefeuille 0.026000000000000023
# On ne hedge pas à cette période
# En période 2
#  delta option 0.554 | Var delta 0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 102.155
#  valeur du portefeuille 43.58733000000001
#  delta portefeuille 0.040000000000000036
# On ne hedge pas à cette période
# En période 3
#  delta option 0.523 | Var delta -0.031000000000000028
#  quantité sous-jacent -0.514 | Prix action 100.51
#  valeur du portefeuille 43.536860000000004
#  delta portefeuille 0.009000000000000008
# On ne hedge pas à cette période
# En période 4
#  delta option 0.523 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 100.495
#  valeur du portefeuille 43.527570000000004
#  delta portefeuille 0.009000000000000008
# On ne hedge pas à cette période
# En période 5
#  delta option 0.535 | Var delta 0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 101.146
#  valeur du portefeuille 43.52795600000001
#  delta portefeuille 0.02100000000000002
# On ne hedge pas à cette période
# En période 6
#  delta option 0.521 | Var delta -0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 100.381
#  valeur du portefeuille 43.50816600000002
#  delta portefeuille 0.007000000000000006
# On ne hedge pas à cette période
# En période 7
#  delta option 0.526 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 100.655
#  valeur du portefeuille 43.50133000000001
#  delta portefeuille 0.01200000000000001
# On ne hedge pas à cette période
# En période 8
#  delta option 0.528 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 100.763
#  valeur du portefeuille 43.493818000000005
#  delta portefeuille 0.014000000000000012
# On ne hedge pas à cette période
# En période 9
#  delta option 0.528 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 100.762
#  valeur du portefeuille 43.48433200000001
#  delta portefeuille 0.014000000000000012
# On ne hedge pas à cette période
# En période 10
#  delta option 0.525 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 100.573
#  valeur du portefeuille 43.47247800000001
#  delta portefeuille 0.01100000000000001
# On ne hedge pas à cette période
# En période 11
#  delta option 0.533 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 101.024
#  valeur du portefeuille 43.469664
#  delta portefeuille 0.019000000000000017
# On ne hedge pas à cette période
# En période 12
#  delta option 0.557 | Var delta 0.02400000000000002
#  quantité sous-jacent -0.514 | Prix action 102.299
#  valeur du portefeuille 43.499314
#  delta portefeuille 0.04300000000000004
# On ne hedge pas à cette période
# En période 13
#  delta option 0.538 | Var delta -0.019000000000000017
#  quantité sous-jacent -0.514 | Prix action 101.265
#  valeur du portefeuille 43.45579
#  delta portefeuille 0.02400000000000002
# On ne hedge pas à cette période
# En période 14
#  delta option 0.558 | Var delta 0.020000000000000018
#  quantité sous-jacent -0.514 | Prix action 102.356
#  valeur du portefeuille 43.483016000000006
#  delta portefeuille 0.04400000000000004
# On ne hedge pas à cette période
# En période 15
#  delta option 0.563 | Var delta 0.004999999999999893
#  quantité sous-jacent -0.514 | Prix action 102.595
#  valeur du portefeuille 43.485170000000004
#  delta portefeuille 0.04899999999999993
# On ne hedge pas à cette période
# En période 16
#  delta option 0.572 | Var delta 0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 103.069
#  valeur du portefeuille 43.500534
#  delta portefeuille 0.05799999999999994
# On ne hedge pas à cette période
# En période 17
#  delta option 0.549 | Var delta -0.02299999999999991
#  quantité sous-jacent -0.514 | Prix action 101.844
#  valeur du portefeuille 43.43418400000001
#  delta portefeuille 0.03500000000000003
# On ne hedge pas à cette période
# En période 18
#  delta option 0.552 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 101.983
#  valeur du portefeuille 43.42973800000001
#  delta portefeuille 0.038000000000000034
# On ne hedge pas à cette période
# En période 19
#  delta option 0.581 | Var delta 0.028999999999999915
#  quantité sous-jacent -0.514 | Prix action 103.574
#  valeur du portefeuille 43.503964
#  delta portefeuille 0.06699999999999995
# On ne hedge pas à cette période
# En période 20
#  delta option 0.56 | Var delta -0.020999999999999908
#  quantité sous-jacent -0.514 | Prix action 102.404
#  valeur du portefeuille 43.428343999999996
#  delta portefeuille 0.04600000000000004
# On ne hedge pas à cette période
# En période 21
#  delta option 0.52 | Var delta -0.040000000000000036
#  quantité sous-jacent -0.514 | Prix action 100.301
#  valeur du portefeuille 43.36428599999999
#  delta portefeuille 0.006000000000000005
# On ne hedge pas à cette période
# En période 22
#  delta option 0.484 | Var delta -0.03600000000000003
#  quantité sous-jacent -0.514 | Prix action 98.481
#  valeur du portefeuille 43.376765999999996
#  delta portefeuille -0.030000000000000027
# On ne hedge pas à cette période
# En période 23
#  delta option 0.489 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 98.751
#  valeur du portefeuille 43.35998599999999
#  delta portefeuille -0.025000000000000022
# On ne hedge pas à cette période
# En période 24
#  delta option 0.538 | Var delta 0.049000000000000044
#  quantité sous-jacent -0.514 | Prix action 101.242
#  valeur du portefeuille 43.34961199999999
#  delta portefeuille 0.02400000000000002
# On ne hedge pas à cette période
# En période 25
#  delta option 0.561 | Var delta 0.02300000000000002
#  quantité sous-jacent -0.514 | Prix action 102.434
#  valeur du portefeuille 43.38192399999999
#  delta portefeuille 0.04700000000000004
# On ne hedge pas à cette période
# En période 26
#  delta option 0.594 | Var delta 0.03299999999999992
#  quantité sous-jacent -0.514 | Prix action 104.238
#  valeur du portefeuille 43.48766799999999
#  delta portefeuille 0.07999999999999996
# On ne hedge pas à cette période
# En période 27
#  delta option 0.596 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 104.34
#  valeur du portefeuille 43.486239999999995
#  delta portefeuille 0.08199999999999996
# On ne hedge pas à cette période
# En période 28
#  delta option 0.623 | Var delta 0.027000000000000024
#  quantité sous-jacent -0.514 | Prix action 105.873
#  valeur du portefeuille 43.62327799999999
#  delta portefeuille 0.10899999999999999
# On ne hedge pas à cette période
# En période 29
#  delta option 0.618 | Var delta -0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 105.567
#  valeur du portefeuille 43.581562
#  delta portefeuille 0.10399999999999998
# On ne hedge pas à cette période
# En période 30
#  delta option 0.63 | Var delta 0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 106.241
#  valeur du portefeuille 43.64712599999999
#  delta portefeuille 0.11599999999999999
# On ne hedge pas à cette période
# En période 31
#  delta option 0.625 | Var delta -0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 105.938
#  valeur du portefeuille 43.60286799999999
#  delta portefeuille 0.11099999999999999
# On ne hedge pas à cette période
# En période 32
#  delta option 0.615 | Var delta -0.010000000000000009
#  quantité sous-jacent -0.514 | Prix action 105.325
#  valeur du portefeuille 43.52894999999998
#  delta portefeuille 0.10099999999999998
# On ne hedge pas à cette période
# En période 33
#  delta option 0.617 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 105.465
#  valeur du portefeuille 43.53398999999998
#  delta portefeuille 0.10299999999999998
# On ne hedge pas à cette période
# En période 34
#  delta option 0.608 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 104.935
#  valeur du portefeuille 43.47240999999998
#  delta portefeuille 0.09399999999999997
# On ne hedge pas à cette période
# En période 35
#  delta option 0.634 | Var delta 0.026000000000000023
#  quantité sous-jacent -0.514 | Prix action 106.377
#  valeur du portefeuille 43.617221999999984
#  delta portefeuille 0.12
# On ne hedge pas à cette période
# En période 36
#  delta option 0.637 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 106.588
#  valeur du portefeuille 43.63376799999998
#  delta portefeuille 0.123
# On ne hedge pas à cette période
# En période 37
#  delta option 0.645 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 107.03
#  valeur du portefeuille 43.68057999999998
#  delta portefeuille 0.131
# On ne hedge pas à cette période
# En période 38
#  delta option 0.639 | Var delta -0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 106.646
#  valeur du portefeuille 43.621955999999976
#  delta portefeuille 0.125
# On ne hedge pas à cette période
# En période 39
#  delta option 0.663 | Var delta 0.02400000000000002
#  quantité sous-jacent -0.514 | Prix action 108.052
#  valeur du portefeuille 43.805271999999974
#  delta portefeuille 0.14900000000000002
# On ne hedge pas à cette période
# En période 40
#  delta option 0.649 | Var delta -0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 107.222
#  valeur du portefeuille 43.67889199999998
#  delta portefeuille 0.135
# On ne hedge pas à cette période
# En période 41
#  delta option 0.662 | Var delta 0.013000000000000012
#  quantité sous-jacent -0.514 | Prix action 107.96
#  valeur du portefeuille 43.77455999999999
#  delta portefeuille 0.14800000000000002
# On ne hedge pas à cette période
# En période 42
#  delta option 0.655 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 107.558
#  valeur du portefeuille 43.70718799999998
#  delta portefeuille 0.14100000000000001
# On ne hedge pas à cette période
# En période 43
#  delta option 0.637 | Var delta -0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 106.499
#  valeur du portefeuille 43.55751399999998
#  delta portefeuille 0.123
# On ne hedge pas à cette période
# En période 44
#  delta option 0.628 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 105.949
#  valeur du portefeuille 43.48321399999998
#  delta portefeuille 0.11399999999999999
# On ne hedge pas à cette période
# En période 45
#  delta option 0.612 | Var delta -0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 105.055
#  valeur du portefeuille 43.378729999999976
#  delta portefeuille 0.09799999999999998
# On ne hedge pas à cette période
# En période 46
#  delta option 0.608 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 104.816
#  valeur du portefeuille 43.34657599999998
#  delta portefeuille 0.09399999999999997
# On ne hedge pas à cette période
# En période 47
#  delta option 0.601 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 104.438
#  valeur du portefeuille 43.30186799999998
#  delta portefeuille 0.08699999999999997
# On ne hedge pas à cette période
# En période 48
#  delta option 0.607 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 104.775
#  valeur du portefeuille 43.322649999999975
#  delta portefeuille 0.09299999999999997
# On ne hedge pas à cette période
# En période 49
#  delta option 0.619 | Var delta 0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 105.39
#  valeur du portefeuille 43.37453999999998
#  delta portefeuille 0.10499999999999998
# On ne hedge pas à cette période
# En période 50
#  delta option 0.616 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 105.222
#  valeur du portefeuille 43.34689199999999
#  delta portefeuille 0.10199999999999998
# On ne hedge pas à cette période
# En période 51
#  delta option 0.616 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 105.188
#  valeur du portefeuille 43.334367999999984
#  delta portefeuille 0.10199999999999998
# On ne hedge pas à cette période
# En période 52
#  delta option 0.621 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 105.501
#  valeur du portefeuille 43.35648599999998
#  delta portefeuille 0.10699999999999998
# On ne hedge pas à cette période
# En période 53
#  delta option 0.611 | Var delta -0.010000000000000009
#  quantité sous-jacent -0.514 | Prix action 104.901
#  valeur du portefeuille 43.28588599999999
#  delta portefeuille 0.09699999999999998
# On ne hedge pas à cette période
# En période 54
#  delta option 0.625 | Var delta 0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 105.675
#  valeur du portefeuille 43.35704999999999
#  delta portefeuille 0.11099999999999999
# On ne hedge pas à cette période
# En période 55
#  delta option 0.642 | Var delta 0.017000000000000015
#  quantité sous-jacent -0.514 | Prix action 106.605
#  valeur du portefeuille 43.458029999999994
#  delta portefeuille 0.128
# On ne hedge pas à cette période
# En période 56
#  delta option 0.646 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 106.827
#  valeur du portefeuille 43.47792199999999
#  delta portefeuille 0.132
# On ne hedge pas à cette période
# En période 57
#  delta option 0.692 | Var delta 0.04599999999999993
#  quantité sous-jacent -0.514 | Prix action 109.533
#  valeur du portefeuille 43.888037999999995
#  delta portefeuille 0.17799999999999994
# On ne hedge pas à cette période
# En période 58
#  delta option 0.709 | Var delta 0.017000000000000015
#  quantité sous-jacent -0.514 | Prix action 110.584
#  valeur du portefeuille 44.075824
#  delta portefeuille 0.19499999999999995
# On ne hedge pas à cette période
# En période 59
#  delta option 0.707 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 110.448
#  valeur du portefeuille 44.040728
#  delta portefeuille 0.19299999999999995
# On ne hedge pas à cette période
# En période 60
#  delta option 0.7 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 110.024
#  valeur du portefeuille 43.951663999999994
#  delta portefeuille 0.18599999999999994
# On ne hedge pas à cette période
# En période 61
#  delta option 0.696 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 109.751
#  valeur du portefeuille 43.892985999999986
#  delta portefeuille 0.18199999999999994
# On ne hedge pas à cette période
# En période 62
#  delta option 0.687 | Var delta -0.008999999999999897
#  quantité sous-jacent -0.514 | Prix action 109.17
#  valeur du portefeuille 43.780619999999985
#  delta portefeuille 0.17300000000000004
# On ne hedge pas à cette période
# En période 63
#  delta option 0.708 | Var delta 0.020999999999999908
#  quantité sous-jacent -0.514 | Prix action 110.461
#  valeur du portefeuille 44.009045999999984
#  delta portefeuille 0.19399999999999995
# On ne hedge pas à cette période
# En période 64
#  delta option 0.696 | Var delta -0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 109.651
#  valeur du portefeuille 43.848385999999984
#  delta portefeuille 0.18199999999999994
# On ne hedge pas à cette période
# En période 65
#  delta option 0.695 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 109.552
#  valeur du portefeuille 43.82127199999997
#  delta portefeuille 0.18099999999999994
# On ne hedge pas à cette période
# En période 66
#  delta option 0.685 | Var delta -0.009999999999999898
#  quantité sous-jacent -0.514 | Prix action 108.941
#  valeur du portefeuille 43.70532599999997
#  delta portefeuille 0.17100000000000004
# On ne hedge pas à cette période
# En période 67
#  delta option 0.705 | Var delta 0.019999999999999907
#  quantité sous-jacent -0.514 | Prix action 110.135
#  valeur du portefeuille 43.91160999999997
#  delta portefeuille 0.19099999999999995
# On ne hedge pas à cette période
# En période 68
#  delta option 0.678 | Var delta -0.026999999999999913
#  quantité sous-jacent -0.514 | Prix action 108.505
#  valeur du portefeuille 43.61342999999998
#  delta portefeuille 0.16400000000000003
# On ne hedge pas à cette période
# En période 69
#  delta option 0.671 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 108.088
#  valeur du portefeuille 43.536767999999974
#  delta portefeuille 0.15700000000000003
# On ne hedge pas à cette période
# En période 70
#  delta option 0.669 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 107.945
#  valeur du portefeuille 43.505269999999975
#  delta portefeuille 0.15500000000000003
# On ne hedge pas à cette période
# En période 71
#  delta option 0.676 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 108.3
#  valeur du portefeuille 43.55179999999997
#  delta portefeuille 0.16200000000000003
# On ne hedge pas à cette période
# En période 72
#  delta option 0.685 | Var delta 0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 108.818
#  valeur du portefeuille 43.628547999999974
#  delta portefeuille 0.17100000000000004
# On ne hedge pas à cette période
# En période 73
#  delta option 0.681 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 108.567
#  valeur du portefeuille 43.57756199999997
#  delta portefeuille 0.16700000000000004
# On ne hedge pas à cette période
# En période 74
#  delta option 0.7 | Var delta 0.018999999999999906
#  quantité sous-jacent -0.514 | Prix action 109.691
#  valeur du portefeuille 43.76582599999997
#  delta portefeuille 0.18599999999999994
# On ne hedge pas à cette période
# En période 75
#  delta option 0.706 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 110.047
#  valeur du portefeuille 43.824841999999975
#  delta portefeuille 0.19199999999999995
# On ne hedge pas à cette période
# En période 76
#  delta option 0.75 | Var delta 0.04400000000000004
#  quantité sous-jacent -0.514 | Prix action 112.92
#  valeur du portefeuille 44.43111999999997
#  delta portefeuille 0.236
# On ne hedge pas à cette période
# En période 77
#  delta option 0.724 | Var delta -0.026000000000000023
#  quantité sous-jacent -0.514 | Prix action 111.145
#  valeur du portefeuille 44.02746999999998
#  delta portefeuille 0.20999999999999996
# On ne hedge pas à cette période
# En période 78
#  delta option 0.735 | Var delta 0.01100000000000001
#  quantité sous-jacent -0.514 | Prix action 111.863
#  valeur du portefeuille 44.174417999999974
#  delta portefeuille 0.22099999999999997
# On ne hedge pas à cette période
# En période 79
#  delta option 0.717 | Var delta -0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 110.64
#  valeur du portefeuille 43.906039999999976
#  delta portefeuille 0.20299999999999996
# On ne hedge pas à cette période
# En période 80
#  delta option 0.702 | Var delta -0.015000000000000013
#  quantité sous-jacent -0.514 | Prix action 109.714
#  valeur du portefeuille 43.71600399999997
#  delta portefeuille 0.18799999999999994
# On ne hedge pas à cette période
# En période 81
#  delta option 0.738 | Var delta 0.03600000000000003
#  quantité sous-jacent -0.514 | Prix action 112.011
#  valeur du portefeuille 44.18234599999997
#  delta portefeuille 0.22399999999999998
# On ne hedge pas à cette période
# En période 82
#  delta option 0.768 | Var delta 0.030000000000000027
#  quantité sous-jacent -0.514 | Prix action 114.07
#  valeur du portefeuille 44.66701999999997
#  delta portefeuille 0.254
# On ne hedge pas à cette période
# En période 83
#  delta option 0.737 | Var delta -0.031000000000000028
#  quantité sous-jacent -0.514 | Prix action 111.869
#  valeur du portefeuille 44.13333399999996
#  delta portefeuille 0.22299999999999998
# On ne hedge pas à cette période
# En période 84
#  delta option 0.733 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 111.602
#  valeur du portefeuille 44.06657199999996
#  delta portefeuille 0.21899999999999997
# On ne hedge pas à cette période
# En période 85
#  delta option 0.732 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 111.519
#  valeur du portefeuille 44.039233999999965
#  delta portefeuille 0.21799999999999997
# On ne hedge pas à cette période
# En période 86
#  delta option 0.693 | Var delta -0.039000000000000035
#  quantité sous-jacent -0.514 | Prix action 109.052
#  valeur du portefeuille 43.539271999999954
#  delta portefeuille 0.17899999999999994
# On ne hedge pas à cette période
# En période 87
#  delta option 0.692 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 108.99
#  valeur du portefeuille 43.51913999999995
#  delta portefeuille 0.17799999999999994
# On ne hedge pas à cette période
# En période 88
#  delta option 0.7 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 109.434
#  valeur du portefeuille 43.590923999999944
#  delta portefeuille 0.18599999999999994
# On ne hedge pas à cette période
# En période 89
#  delta option 0.705 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 109.677
#  valeur du portefeuille 43.62702199999994
#  delta portefeuille 0.19099999999999995
# On ne hedge pas à cette période
# En période 90
#  delta option 0.665 | Var delta -0.039999999999999925
#  quantité sous-jacent -0.514 | Prix action 107.405
#  valeur du portefeuille 43.22782999999994
#  delta portefeuille 0.15100000000000002
# On ne hedge pas à cette période
# En période 91
#  delta option 0.688 | Var delta 0.02299999999999991
#  quantité sous-jacent -0.514 | Prix action 108.652
#  valeur du portefeuille 43.42087199999994
#  delta portefeuille 0.17399999999999993
# On ne hedge pas à cette période
# En période 92
#  delta option 0.693 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 108.924
#  valeur du portefeuille 43.46006399999994
#  delta portefeuille 0.17899999999999994
# On ne hedge pas à cette période
# En période 93
#  delta option 0.692 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 108.848
#  valeur du portefeuille 43.43612799999994
#  delta portefeuille 0.17799999999999994
# On ne hedge pas à cette période
# En période 94
#  delta option 0.677 | Var delta -0.014999999999999902
#  quantité sous-jacent -0.514 | Prix action 107.986
#  valeur du portefeuille 43.28019599999994
#  delta portefeuille 0.16300000000000003
# On ne hedge pas à cette période
# En période 95
#  delta option 0.692 | Var delta 0.014999999999999902
#  quantité sous-jacent -0.514 | Prix action 108.788
#  valeur du portefeuille 43.40696799999994
#  delta portefeuille 0.17799999999999994
# On ne hedge pas à cette période
# En période 96
#  delta option 0.71 | Var delta 0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 109.833
#  valeur du portefeuille 43.59183799999994
#  delta portefeuille 0.19599999999999995
# On ne hedge pas à cette période
# En période 97
#  delta option 0.701 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 109.274
#  valeur du portefeuille 43.47616399999994
#  delta portefeuille 0.18699999999999994
# On ne hedge pas à cette période
# En période 98
#  delta option 0.703 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 109.37
#  valeur du portefeuille 43.484819999999935
#  delta portefeuille 0.18899999999999995
# On ne hedge pas à cette période
# En période 99
#  delta option 0.719 | Var delta 0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 110.315
#  valeur du portefeuille 43.661089999999945
#  delta portefeuille 0.20499999999999996
# On ne hedge pas à cette période
# En période 100
#  delta option 0.681 | Var delta -0.03799999999999992
#  quantité sous-jacent -0.514 | Prix action 108.075
#  valeur du portefeuille 43.23444999999994
#  delta portefeuille 0.16700000000000004
# On ne hedge pas à cette période
# En période 101
#  delta option 0.683 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 108.202
#  valeur du portefeuille 43.24617199999994
#  delta portefeuille 0.16900000000000004
# On ne hedge pas à cette période
# En période 102
#  delta option 0.643 | Var delta -0.040000000000000036
#  quantité sous-jacent -0.514 | Prix action 106.057
#  valeur du portefeuille 42.91570199999993
#  delta portefeuille 0.129
# On ne hedge pas à cette période
# En période 103
#  delta option 0.623 | Var delta -0.020000000000000018
#  quantité sous-jacent -0.514 | Prix action 105.032
#  valeur du portefeuille 42.78255199999993
#  delta portefeuille 0.10899999999999999
# On ne hedge pas à cette période
# En période 104
#  delta option 0.634 | Var delta 0.01100000000000001
#  quantité sous-jacent -0.514 | Prix action 105.544
#  valeur du portefeuille 42.83038399999994
#  delta portefeuille 0.12
# On ne hedge pas à cette période
# En période 105
#  delta option 0.631 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 105.379
#  valeur du portefeuille 42.79919399999993
#  delta portefeuille 0.11699999999999999
# On ne hedge pas à cette période
# En période 106
#  delta option 0.622 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 104.932
#  valeur du portefeuille 42.73895199999993
#  delta portefeuille 0.10799999999999998
# On ne hedge pas à cette période
# En période 107
#  delta option 0.615 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 104.602
#  valeur du portefeuille 42.69257199999993
#  delta portefeuille 0.10099999999999998
# On ne hedge pas à cette période
# En période 108
#  delta option 0.634 | Var delta 0.019000000000000017
#  quantité sous-jacent -0.514 | Prix action 105.529
#  valeur du portefeuille 42.78509399999993
#  delta portefeuille 0.12
# On ne hedge pas à cette période
# En période 109
#  delta option 0.65 | Var delta 0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 106.307
#  valeur du portefeuille 42.87320199999993
#  delta portefeuille 0.136
# On ne hedge pas à cette période
# En période 110
#  delta option 0.633 | Var delta -0.017000000000000015
#  quantité sous-jacent -0.514 | Prix action 105.429
#  valeur du portefeuille 42.75049399999993
#  delta portefeuille 0.119
# On ne hedge pas à cette période
# En période 111
#  delta option 0.64 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 105.747
#  valeur du portefeuille 42.77904199999993
#  delta portefeuille 0.126
# On ne hedge pas à cette période
# En période 112
#  delta option 0.629 | Var delta -0.01100000000000001
#  quantité sous-jacent -0.514 | Prix action 105.221
#  valeur du portefeuille 42.704405999999935
#  delta portefeuille 0.11499999999999999
# On ne hedge pas à cette période
# En période 113
#  delta option 0.682 | Var delta 0.05300000000000005
#  quantité sous-jacent -0.514 | Prix action 107.897
#  valeur du portefeuille 43.072941999999934
#  delta portefeuille 0.16800000000000004
# On ne hedge pas à cette période
# En période 114
#  delta option 0.666 | Var delta -0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 107.06
#  valeur du portefeuille 42.92915999999994
#  delta portefeuille 0.15200000000000002
# On ne hedge pas à cette période
# En période 115
#  delta option 0.66 | Var delta -0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 106.704
#  valeur du portefeuille 42.865143999999944
#  delta portefeuille 0.14600000000000002
# On ne hedge pas à cette période
# En période 116
#  delta option 0.652 | Var delta -0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 106.309
#  valeur du portefeuille 42.798173999999946
#  delta portefeuille 0.138
# On ne hedge pas à cette période
# En période 117
#  delta option 0.643 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 105.816
#  valeur du portefeuille 42.72157599999994
#  delta portefeuille 0.129
# On ne hedge pas à cette période
# En période 118
#  delta option 0.646 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 105.966
#  valeur du portefeuille 42.730475999999946
#  delta portefeuille 0.132
# On ne hedge pas à cette période
# En période 119
#  delta option 0.652 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 106.264
#  valeur du portefeuille 42.75930399999995
#  delta portefeuille 0.138
# On ne hedge pas à cette période
# En période 120
#  delta option 0.615 | Var delta -0.03700000000000003
#  quantité sous-jacent -0.514 | Prix action 104.473
#  valeur du portefeuille 42.53287799999995
#  delta portefeuille 0.10099999999999998
# On ne hedge pas à cette période
# En période 121
#  delta option 0.602 | Var delta -0.013000000000000012
#  quantité sous-jacent -0.514 | Prix action 103.842
#  valeur du portefeuille 42.46221199999995
#  delta portefeuille 0.08799999999999997
# On ne hedge pas à cette période
# En période 122
#  delta option 0.571 | Var delta -0.031000000000000028
#  quantité sous-jacent -0.514 | Prix action 102.411
#  valeur du portefeuille 42.34674599999995
#  delta portefeuille 0.05699999999999994
# On ne hedge pas à cette période
# En période 123
#  delta option 0.6 | Var delta 0.029000000000000026
#  quantité sous-jacent -0.514 | Prix action 103.739
#  valeur du portefeuille 42.429153999999954
#  delta portefeuille 0.08599999999999997
# On ne hedge pas à cette période
# En période 124
#  delta option 0.657 | Var delta 0.05700000000000005
#  quantité sous-jacent -0.514 | Prix action 106.445
#  valeur du portefeuille 42.72926999999996
#  delta portefeuille 0.14300000000000002
# On ne hedge pas à cette période
# En période 125
#  delta option 0.688 | Var delta 0.030999999999999917
#  quantité sous-jacent -0.514 | Prix action 107.992
#  valeur du portefeuille 42.96411199999995
#  delta portefeuille 0.17399999999999993
# On ne hedge pas à cette période
# En période 126
#  delta option 0.695 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 108.378
#  valeur du portefeuille 43.021707999999954
#  delta portefeuille 0.18099999999999994
# On ne hedge pas à cette période
# En période 127
#  delta option 0.717 | Var delta 0.02200000000000002
#  quantité sous-jacent -0.514 | Prix action 109.539
#  valeur du portefeuille 43.23495399999996
#  delta portefeuille 0.20299999999999996
# On ne hedge pas à cette période
# En période 128
#  delta option 0.72 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 109.724
#  valeur du portefeuille 43.26286399999996
#  delta portefeuille 0.20599999999999996
# On ne hedge pas à cette période
# En période 129
#  delta option 0.753 | Var delta 0.03300000000000003
#  quantité sous-jacent -0.514 | Prix action 111.637
#  valeur du portefeuille 43.67958199999996
#  delta portefeuille 0.239
# On ne hedge pas à cette période
# En période 130
#  delta option 0.766 | Var delta 0.013000000000000012
#  quantité sous-jacent -0.514 | Prix action 112.415
#  valeur du portefeuille 43.86168999999995
#  delta portefeuille 0.252
# On ne hedge pas à cette période
# En période 131
#  delta option 0.762 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 112.138
#  valeur du portefeuille 43.784067999999955
#  delta portefeuille 0.248
# On ne hedge pas à cette période
# En période 132
#  delta option 0.741 | Var delta -0.02100000000000002
#  quantité sous-jacent -0.514 | Prix action 110.814
#  valeur du portefeuille 43.46060399999996
#  delta portefeuille 0.22699999999999998
# On ne hedge pas à cette période
# En période 133
#  delta option 0.729 | Var delta -0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 110.068
#  valeur du portefeuille 43.28604799999996
#  delta portefeuille 0.21499999999999997
# On ne hedge pas à cette période
# En période 134
#  delta option 0.735 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 110.424
#  valeur du portefeuille 43.353063999999954
#  delta portefeuille 0.22099999999999997
# On ne hedge pas à cette période
# En période 135
#  delta option 0.711 | Var delta -0.02400000000000002
#  quantité sous-jacent -0.514 | Prix action 109.01
#  valeur du portefeuille 43.04785999999995
#  delta portefeuille 0.19699999999999995
# On ne hedge pas à cette période
# En période 136
#  delta option 0.706 | Var delta -0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 108.751
#  valeur du portefeuille 42.98698599999995
#  delta portefeuille 0.19199999999999995
# On ne hedge pas à cette période
# En période 137
#  delta option 0.734 | Var delta 0.028000000000000025
#  quantité sous-jacent -0.514 | Prix action 110.282
#  valeur du portefeuille 43.29305199999995
#  delta portefeuille 0.21999999999999997
# On ne hedge pas à cette période
# En période 138
#  delta option 0.735 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 110.309
#  valeur du portefeuille 43.28917399999996
#  delta portefeuille 0.22099999999999997
# On ne hedge pas à cette période
# En période 139
#  delta option 0.774 | Var delta 0.039000000000000035
#  quantité sous-jacent -0.514 | Prix action 112.62
#  valeur du portefeuille 43.83531999999995
#  delta portefeuille 0.26
# On ne hedge pas à cette période
# En période 140
#  delta option 0.799 | Var delta 0.025000000000000022
#  quantité sous-jacent -0.514 | Prix action 114.333
#  valeur du portefeuille 44.293837999999965
#  delta portefeuille 0.28500000000000003
# On ne hedge pas à cette période
# En période 141
#  delta option 0.795 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 113.983
#  valeur du portefeuille 44.18773799999997
#  delta portefeuille 0.281
# On ne hedge pas à cette période
# En période 142
#  delta option 0.771 | Var delta -0.02400000000000002
#  quantité sous-jacent -0.514 | Prix action 112.366
#  valeur du portefeuille 43.74387599999997
#  delta portefeuille 0.257
# On ne hedge pas à cette période
# En période 143
#  delta option 0.771 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 112.303
#  valeur du portefeuille 43.71825799999996
#  delta portefeuille 0.257
# On ne hedge pas à cette période
# En période 144
#  delta option 0.762 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 111.734
#  valeur du portefeuille 43.565723999999975
#  delta portefeuille 0.248
# On ne hedge pas à cette période
# En période 145
#  delta option 0.77 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 112.17
#  valeur du portefeuille 43.666619999999966
#  delta portefeuille 0.256
# On ne hedge pas à cette période
# En période 146
#  delta option 0.799 | Var delta 0.029000000000000026
#  quantité sous-jacent -0.514 | Prix action 114.076
#  valeur du portefeuille 44.17293599999997
#  delta portefeuille 0.28500000000000003
# On ne hedge pas à cette période
# En période 147
#  delta option 0.78 | Var delta -0.019000000000000017
#  quantité sous-jacent -0.514 | Prix action 112.736
#  valeur du portefeuille 43.795695999999964
#  delta portefeuille 0.266
# On ne hedge pas à cette période
# En période 148
#  delta option 0.773 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 112.272
#  valeur du portefeuille 43.66519199999996
#  delta portefeuille 0.259
# On ne hedge pas à cette période
# En période 149
#  delta option 0.779 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 112.657
#  valeur du portefeuille 43.75730199999997
#  delta portefeuille 0.265
# On ne hedge pas à cette période
# En période 150
#  delta option 0.8 | Var delta 0.02100000000000002
#  quantité sous-jacent -0.514 | Prix action 113.998
#  valeur du portefeuille 44.11902799999996
#  delta portefeuille 0.28600000000000003
# On ne hedge pas à cette période
# En période 151
#  delta option 0.809 | Var delta 0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 114.602
#  valeur du portefeuille 44.28657199999995
#  delta portefeuille 0.29500000000000004
# On ne hedge pas à cette période
# En période 152
#  delta option 0.816 | Var delta 0.006999999999999895
#  quantité sous-jacent -0.514 | Prix action 115.094
#  valeur du portefeuille 44.42568399999996
#  delta portefeuille 0.30199999999999994
# On ne hedge pas à cette période
# En période 153
#  delta option 0.838 | Var delta 0.02200000000000002
#  quantité sous-jacent -0.514 | Prix action 116.719
#  valeur du portefeuille 44.927433999999955
#  delta portefeuille 0.32399999999999995
# On ne hedge pas à cette période
# En période 154
#  delta option 0.845 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 117.317
#  valeur du portefeuille 45.11706199999996
#  delta portefeuille 0.33099999999999996
# On ne hedge pas à cette période
# En période 155
#  delta option 0.842 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 117.02
#  valeur du portefeuille 45.01271999999996
#  delta portefeuille 0.32799999999999996
# On ne hedge pas à cette période
# En période 156
#  delta option 0.844 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 117.084
#  valeur du portefeuille 45.026823999999955
#  delta portefeuille 0.32999999999999996
# On ne hedge pas à cette période
# En période 157
#  delta option 0.834 | Var delta -0.010000000000000009
#  quantité sous-jacent -0.514 | Prix action 116.214
#  valeur du portefeuille 44.73800399999996
#  delta portefeuille 0.31999999999999995
# On ne hedge pas à cette période
# En période 158
#  delta option 0.842 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 116.875
#  valeur du portefeuille 44.94524999999996
#  delta portefeuille 0.32799999999999996
# On ne hedge pas à cette période
# En période 159
#  delta option 0.856 | Var delta 0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 118.027
#  valeur du portefeuille 45.326121999999955
#  delta portefeuille 0.34199999999999997
# On ne hedge pas à cette période
# En période 160
#  delta option 0.811 | Var delta -0.04499999999999993
#  quantité sous-jacent -0.514 | Prix action 114.396
#  valeur du portefeuille 44.15445599999995
#  delta portefeuille 0.29700000000000004
# On ne hedge pas à cette période
# En période 161
#  delta option 0.832 | Var delta 0.020999999999999908
#  quantité sous-jacent -0.514 | Prix action 115.858
#  valeur du portefeuille 44.59698799999995
#  delta portefeuille 0.31799999999999995
# On ne hedge pas à cette période
# En période 162
#  delta option 0.831 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 115.783
#  valeur du portefeuille 44.565537999999954
#  delta portefeuille 0.31699999999999995
# On ne hedge pas à cette période
# En période 163
#  delta option 0.839 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 116.337
#  valeur du portefeuille 44.736781999999955
#  delta portefeuille 0.32499999999999996
# On ne hedge pas à cette période
# En période 164
#  delta option 0.849 | Var delta 0.010000000000000009
#  quantité sous-jacent -0.514 | Prix action 117.14
#  valeur du portefeuille 44.99503999999996
#  delta portefeuille 0.33499999999999996
# On ne hedge pas à cette période
# En période 165
#  delta option 0.814 | Var delta -0.03500000000000003
#  quantité sous-jacent -0.514 | Prix action 114.353
#  valeur du portefeuille 44.10155799999997
#  delta portefeuille 0.29999999999999993
# On ne hedge pas à cette période
# En période 166
#  delta option 0.793 | Var delta -0.020999999999999908
#  quantité sous-jacent -0.514 | Prix action 112.924
#  valeur du portefeuille 43.67906399999996
#  delta portefeuille 0.279
# On ne hedge pas à cette période
# En période 167
#  delta option 0.787 | Var delta -0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 112.525
#  valeur du portefeuille 43.55914999999996
#  delta portefeuille 0.273
# On ne hedge pas à cette période
# En période 168
#  delta option 0.773 | Var delta -0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 111.59
#  valeur du portefeuille 43.30173999999997
#  delta portefeuille 0.259
# On ne hedge pas à cette période
# En période 169
#  delta option 0.779 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 111.905
#  valeur du portefeuille 43.37382999999997
#  delta portefeuille 0.265
# On ne hedge pas à cette période
# En période 170
#  delta option 0.769 | Var delta -0.010000000000000009
#  quantité sous-jacent -0.514 | Prix action 111.297
#  valeur du portefeuille 43.20634199999998
#  delta portefeuille 0.255
# On ne hedge pas à cette période
# En période 171
#  delta option 0.733 | Var delta -0.03600000000000003
#  quantité sous-jacent -0.514 | Prix action 109.315
#  valeur du portefeuille 42.72508999999998
#  delta portefeuille 0.21899999999999997
# On ne hedge pas à cette période
# En période 172
#  delta option 0.747 | Var delta 0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 110.012
#  valeur du portefeuille 42.87183199999998
#  delta portefeuille 0.23299999999999998
# On ne hedge pas à cette période
# En période 173
#  delta option 0.77 | Var delta 0.02300000000000002
#  quantité sous-jacent -0.514 | Prix action 111.28
#  valeur du portefeuille 43.17207999999998
#  delta portefeuille 0.256
# On ne hedge pas à cette période
# En période 174
#  delta option 0.782 | Var delta 0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 111.933
#  valeur du portefeuille 43.33343799999998
#  delta portefeuille 0.268
# On ne hedge pas à cette période
# En période 175
#  delta option 0.768 | Var delta -0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 111.095
#  valeur du portefeuille 43.10516999999998
#  delta portefeuille 0.254
# On ne hedge pas à cette période
# En période 176
#  delta option 0.763 | Var delta -0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 110.786
#  valeur du portefeuille 43.01699599999998
#  delta portefeuille 0.249
# On ne hedge pas à cette période
# En période 177
#  delta option 0.775 | Var delta 0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 111.418
#  valeur du portefeuille 43.168147999999974
#  delta portefeuille 0.261
# On ne hedge pas à cette période
# En période 178
#  delta option 0.788 | Var delta 0.013000000000000012
#  quantité sous-jacent -0.514 | Prix action 112.118
#  valeur du portefeuille 43.34534799999998
#  delta portefeuille 0.274
# On ne hedge pas à cette période
# En période 179
#  delta option 0.807 | Var delta 0.019000000000000017
#  quantité sous-jacent -0.514 | Prix action 113.299
#  valeur du portefeuille 43.671313999999974
#  delta portefeuille 0.29300000000000004
# On ne hedge pas à cette période
# En période 180
#  delta option 0.802 | Var delta -0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 112.945
#  valeur du portefeuille 43.559269999999984
#  delta portefeuille 0.28800000000000003
# On ne hedge pas à cette période
# En période 181
#  delta option 0.775 | Var delta -0.027000000000000024
#  quantité sous-jacent -0.514 | Prix action 111.271
#  valeur du portefeuille 43.08970599999998
#  delta portefeuille 0.261
# On ne hedge pas à cette période
# En période 182
#  delta option 0.761 | Var delta -0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 110.477
#  valeur du portefeuille 42.87682199999998
#  delta portefeuille 0.247
# On ne hedge pas à cette période
# En période 183
#  delta option 0.773 | Var delta 0.01200000000000001
#  quantité sous-jacent -0.514 | Prix action 111.09
#  valeur du portefeuille 43.021739999999994
#  delta portefeuille 0.259
# On ne hedge pas à cette période
# En période 184
#  delta option 0.789 | Var delta 0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 111.952
#  valeur du portefeuille 43.241671999999994
#  delta portefeuille 0.275
# On ne hedge pas à cette période
# En période 185
#  delta option 0.83 | Var delta 0.040999999999999925
#  quantité sous-jacent -0.514 | Prix action 114.584
#  valeur du portefeuille 44.01182399999999
#  delta portefeuille 0.31599999999999995
# On ne hedge pas à cette période
# En période 186
#  delta option 0.833 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 114.719
#  valeur du portefeuille 44.04643399999999
#  delta portefeuille 0.31899999999999995
# On ne hedge pas à cette période
# En période 187
#  delta option 0.837 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 115.007
#  valeur du portefeuille 44.13140199999999
#  delta portefeuille 0.32299999999999995
# On ne hedge pas à cette période
# En période 188
#  delta option 0.835 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 114.787
#  valeur du portefeuille 44.05248199999998
#  delta portefeuille 0.32099999999999995
# On ne hedge pas à cette période
# En période 189
#  delta option 0.829 | Var delta -0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 114.294
#  valeur du portefeuille 43.887883999999985
#  delta portefeuille 0.31499999999999995
# On ne hedge pas à cette période
# En période 190
#  delta option 0.842 | Var delta 0.013000000000000012
#  quantité sous-jacent -0.514 | Prix action 115.227
#  valeur du portefeuille 44.18032199999998
#  delta portefeuille 0.32799999999999996
# On ne hedge pas à cette période
# En période 191
#  delta option 0.849 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 115.648
#  valeur du portefeuille 44.31192799999999
#  delta portefeuille 0.33499999999999996
# On ne hedge pas à cette période
# En période 192
#  delta option 0.846 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 115.391
#  valeur du portefeuille 44.21902599999998
#  delta portefeuille 0.33199999999999996
# On ne hedge pas à cette période
# En période 193
#  delta option 0.828 | Var delta -0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 114.088
#  valeur du portefeuille 43.78976799999999
#  delta portefeuille 0.31399999999999995
# On ne hedge pas à cette période
# En période 194
#  delta option 0.827 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 113.935
#  valeur du portefeuille 43.73340999999998
#  delta portefeuille 0.31299999999999994
# On ne hedge pas à cette période
# En période 195
#  delta option 0.82 | Var delta -0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 113.463
#  valeur du portefeuille 43.57901799999998
#  delta portefeuille 0.30599999999999994
# On ne hedge pas à cette période
# En période 196
#  delta option 0.843 | Var delta 0.02300000000000002
#  quantité sous-jacent -0.514 | Prix action 114.958
#  valeur du portefeuille 44.045587999999974
#  delta portefeuille 0.32899999999999996
# On ne hedge pas à cette période
# En période 197
#  delta option 0.859 | Var delta 0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 116.097
#  valeur du portefeuille 44.42214199999998
#  delta portefeuille 0.345
# On ne hedge pas à cette période
# En période 198
#  delta option 0.843 | Var delta -0.016000000000000014
#  quantité sous-jacent -0.514 | Prix action 114.855
#  valeur du portefeuille 43.99552999999997
#  delta portefeuille 0.32899999999999996
# On ne hedge pas à cette période
# En période 199
#  delta option 0.862 | Var delta 0.019000000000000017
#  quantité sous-jacent -0.514 | Prix action 116.26
#  valeur du portefeuille 44.46435999999997
#  delta portefeuille 0.348
# On ne hedge pas à cette période
# En période 200
#  delta option 0.854 | Var delta -0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 115.56
#  valeur du portefeuille 44.216159999999974
#  delta portefeuille 0.33999999999999997
# On ne hedge pas à cette période
# En période 201
#  delta option 0.857 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 115.715
#  valeur du portefeuille 44.26248999999997
#  delta portefeuille 0.34299999999999997
# On ne hedge pas à cette période
# En période 202
#  delta option 0.875 | Var delta 0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 117.174
#  valeur du portefeuille 44.769563999999974
#  delta portefeuille 0.361
# On ne hedge pas à cette période
# En période 203
#  delta option 0.861 | Var delta -0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 115.918
#  valeur du portefeuille 44.318147999999965
#  delta portefeuille 0.347
# On ne hedge pas à cette période
# En période 204
#  delta option 0.864 | Var delta 0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 116.106
#  valeur du portefeuille 44.37651599999998
#  delta portefeuille 0.35
# On ne hedge pas à cette période
# En période 205
#  delta option 0.846 | Var delta -0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 114.734
#  valeur du portefeuille 43.90072399999998
#  delta portefeuille 0.33199999999999996
# On ne hedge pas à cette période
# En période 206
#  delta option 0.812 | Var delta -0.03399999999999992
# ...
#  valeur du portefeuille 41.08769199999996
#  delta portefeuille 0.32299999999999995
# On ne hedge pas à cette période
# En période 294
#  delta option 0.844 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 109.231
#  valeur du portefeuille 41.14126599999996
#  delta portefeuille 0.32999999999999996
# On ne hedge pas à cette période
# En période 295
#  delta option 0.873 | Var delta 0.029000000000000026
#  quantité sous-jacent -0.514 | Prix action 110.473
#  valeur du portefeuille 41.55687799999996
#  delta portefeuille 0.359
# On ne hedge pas à cette période
# En période 296
#  delta option 0.882 | Var delta 0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 110.88
#  valeur du portefeuille 41.69267999999996
#  delta portefeuille 0.368
# On ne hedge pas à cette période
# En période 297
#  delta option 0.889 | Var delta 0.007000000000000006
#  quantité sous-jacent -0.514 | Prix action 111.115
#  valeur du portefeuille 41.76888999999996
#  delta portefeuille 0.375
# On ne hedge pas à cette période
# En période 298
#  delta option 0.887 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 110.94
#  valeur du portefeuille 41.69283999999996
#  delta portefeuille 0.373
# On ne hedge pas à cette période
# En période 299
#  delta option 0.892 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 111.125
#  valeur du portefeuille 41.75074999999997
#  delta portefeuille 0.378
# On ne hedge pas à cette période
# En période 300
#  delta option 0.91 | Var delta 0.018000000000000016
#  quantité sous-jacent -0.514 | Prix action 112.088
#  valeur du portefeuille 42.113767999999965
#  delta portefeuille 0.396
# On ne hedge pas à cette période
# En période 301
#  delta option 0.925 | Var delta 0.015000000000000013
#  quantité sous-jacent -0.514 | Prix action 112.971
#  valeur du portefeuille 42.461905999999956
#  delta portefeuille 0.41100000000000003
# On ne hedge pas à cette période
# En période 302
#  delta option 0.939 | Var delta 0.013999999999999901
#  quantité sous-jacent -0.514 | Prix action 114.01
#  valeur du portefeuille 42.889859999999956
#  delta portefeuille 0.42499999999999993
# On ne hedge pas à cette période
# En période 303
#  delta option 0.937 | Var delta -0.0019999999999998908
#  quantité sous-jacent -0.514 | Prix action 113.718
#  valeur du portefeuille 42.75994799999995
#  delta portefeuille 0.42300000000000004
# On ne hedge pas à cette période
# En période 304
#  delta option 0.928 | Var delta -0.009000000000000008
#  quantité sous-jacent -0.514 | Prix action 112.887
#  valeur du portefeuille 42.40408199999996
#  delta portefeuille 0.41400000000000003
# On ne hedge pas à cette période
# En période 305
#  delta option 0.922 | Var delta -0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 112.325
#  valeur du portefeuille 42.16494999999996
#  delta portefeuille 0.40800000000000003
# On ne hedge pas à cette période
# En période 306
#  delta option 0.93 | Var delta 0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 112.731
#  valeur du portefeuille 42.324265999999966
#  delta portefeuille 0.41600000000000004
# On ne hedge pas à cette période
# En période 307
#  delta option 0.953 | Var delta 0.02299999999999991
#  quantité sous-jacent -0.514 | Prix action 114.642
#  valeur du portefeuille 43.13601199999997
#  delta portefeuille 0.43899999999999995
# On ne hedge pas à cette période
# En période 308
#  delta option 0.957 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 114.924
#  valeur du portefeuille 43.25506399999996
#  delta portefeuille 0.44299999999999995
# On ne hedge pas à cette période
# En période 309
#  delta option 0.962 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 115.502
#  valeur du portefeuille 43.50897199999997
#  delta portefeuille 0.44799999999999995
# On ne hedge pas à cette période
# En période 310
#  delta option 0.945 | Var delta -0.017000000000000015
#  quantité sous-jacent -0.514 | Prix action 113.508
#  valeur du portefeuille 42.62588799999997
#  delta portefeuille 0.43099999999999994
# On ne hedge pas à cette période
# En période 311
#  delta option 0.973 | Var delta 0.028000000000000025
#  quantité sous-jacent -0.514 | Prix action 116.731
#  valeur du portefeuille 44.062265999999966
#  delta portefeuille 0.45899999999999996
# On ne hedge pas à cette période
# En période 312
#  delta option 0.965 | Var delta -0.008000000000000007
#  quantité sous-jacent -0.514 | Prix action 115.384
#  valeur du portefeuille 43.44662399999997
#  delta portefeuille 0.45099999999999996
# On ne hedge pas à cette période
# En période 313
#  delta option 0.979 | Var delta 0.014000000000000012
#  quantité sous-jacent -0.514 | Prix action 117.594
#  valeur du portefeuille 44.45768399999997
#  delta portefeuille 0.46499999999999997
# On ne hedge pas à cette période
# En période 314
#  delta option 0.976 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 116.905
#  valeur du portefeuille 44.137829999999965
#  delta portefeuille 0.46199999999999997
# On ne hedge pas à cette période
# En période 315
#  delta option 0.982 | Var delta 0.006000000000000005
#  quantité sous-jacent -0.514 | Prix action 118.077
#  valeur du portefeuille 44.68242199999997
#  delta portefeuille 0.46799999999999997
# On ne hedge pas à cette période
# En période 316
#  delta option 0.986 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 119.082
#  valeur du portefeuille 45.15485199999998
#  delta portefeuille 0.472
# On ne hedge pas à cette période
# En période 317
#  delta option 0.986 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 119.156
#  valeur du portefeuille 45.19081599999997
#  delta portefeuille 0.472
# On ne hedge pas à cette période
# En période 318
#  delta option 0.987 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 118.942
#  valeur du portefeuille 45.090811999999985
#  delta portefeuille 0.473
# On ne hedge pas à cette période
# En période 319
#  delta option 0.984 | Var delta -0.0030000000000000027
#  quantité sous-jacent -0.514 | Prix action 117.77
#  valeur du portefeuille 44.53821999999998
#  delta portefeuille 0.47
# On ne hedge pas à cette période
# En période 320
#  delta option 0.985 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 117.698
#  valeur du portefeuille 44.504227999999976
#  delta portefeuille 0.471
# On ne hedge pas à cette période
# En période 321
#  delta option 0.989 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 119.056
#  valeur du portefeuille 45.147215999999986
#  delta portefeuille 0.475
# On ne hedge pas à cette période
# En période 322
#  delta option 0.99 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 119.514
#  valeur du portefeuille 45.36580399999998
#  delta portefeuille 0.476
# On ne hedge pas à cette période
# En période 323
#  delta option 0.989 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 118.407
#  valeur du portefeuille 44.84180199999999
#  delta portefeuille 0.475
# On ne hedge pas à cette période
# En période 324
#  delta option 0.991 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 119.845
#  valeur du portefeuille 45.52766999999999
#  delta portefeuille 0.477
# On ne hedge pas à cette période
# En période 325
#  delta option 0.99 | Var delta -0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 118.338
#  valeur du portefeuille 44.81026799999999
#  delta portefeuille 0.476
# On ne hedge pas à cette période
# En période 326
#  delta option 0.991 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 118.591
#  valeur du portefeuille 44.932225999999986
#  delta portefeuille 0.477
# On ne hedge pas à cette période
# En période 327
#  delta option 0.989 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 117.484
#  valeur du portefeuille 44.406223999999995
#  delta portefeuille 0.475
# On ne hedge pas à cette période
# En période 328
#  delta option 0.987 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 116.519
#  valeur du portefeuille 43.94923399999999
#  delta portefeuille 0.473
# On ne hedge pas à cette période
# En période 329
#  delta option 0.991 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 117.837
#  valeur du portefeuille 44.57678199999999
#  delta portefeuille 0.477
# On ne hedge pas à cette période
# En période 330
#  delta option 0.991 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 117.261
#  valeur du portefeuille 44.30284599999999
#  delta portefeuille 0.477
# On ne hedge pas à cette période
# En période 331
#  delta option 0.987 | Var delta -0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 115.409
#  valeur du portefeuille 43.42377399999999
#  delta portefeuille 0.473
# On ne hedge pas à cette période
# En période 332
#  delta option 0.985 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 114.754
#  valeur du portefeuille 43.11444399999998
#  delta portefeuille 0.471
# On ne hedge pas à cette période
# En période 333
#  delta option 0.989 | Var delta 0.0040000000000000036
#  quantité sous-jacent -0.514 | Prix action 115.66
#  valeur du portefeuille 43.54275999999999
#  delta portefeuille 0.475
# On ne hedge pas à cette période
# En période 334
#  delta option 0.987 | Var delta -0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 114.774
#  valeur du portefeuille 43.12216399999998
#  delta portefeuille 0.473
# On ne hedge pas à cette période
# En période 335
#  delta option 0.992 | Var delta 0.0050000000000000044
#  quantité sous-jacent -0.514 | Prix action 116.236
#  valeur du portefeuille 43.818695999999974
#  delta portefeuille 0.478
# On ne hedge pas à cette période
# En période 336
#  delta option 0.994 | Var delta 0.0020000000000000018
#  quantité sous-jacent -0.514 | Prix action 117.463
#  valeur du portefeuille 44.408017999999984
#  delta portefeuille 0.48
# On ne hedge pas à cette période
# En période 337
#  delta option 0.995 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 117.547
#  valeur du portefeuille 44.44984199999999
#  delta portefeuille 0.481
# On ne hedge pas à cette période
# En période 338
#  delta option 0.996 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 118.994
#  valeur du portefeuille 45.14808399999998
#  delta portefeuille 0.482
# On ne hedge pas à cette période
# En période 339
#  delta option 0.996 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 121.331
#  valeur du portefeuille 46.276865999999984
#  delta portefeuille 0.482
# On ne hedge pas à cette période
# En période 340
#  delta option 0.996 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 118.831
#  valeur du portefeuille 45.07386599999998
#  delta portefeuille 0.482
# On ne hedge pas à cette période
# En période 341
#  delta option 0.997 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 120.272
#  valeur du portefeuille 45.77219199999999
#  delta portefeuille 0.483
# On ne hedge pas à cette période
# En période 342
#  delta option 0.997 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 121.035
#  valeur du portefeuille 46.14300999999999
#  delta portefeuille 0.483
# On ne hedge pas à cette période
# En période 343
#  delta option 0.997 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 120.619
#  valeur du portefeuille 45.94483399999998
#  delta portefeuille 0.483
# On ne hedge pas à cette période
# En période 344
#  delta option 0.997 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 121.454
#  valeur du portefeuille 46.350643999999974
#  delta portefeuille 0.483
# On ne hedge pas à cette période
# En période 345
#  delta option 0.997 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 121.953
#  valeur du portefeuille 46.59515799999997
#  delta portefeuille 0.483
# On ne hedge pas à cette période
# En période 346
#  delta option 0.997 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 121.213
#  valeur du portefeuille 46.24051799999998
#  delta portefeuille 0.483
# On ne hedge pas à cette période
# En période 347
#  delta option 0.998 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 123.109
#  valeur du portefeuille 47.15997399999998
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 348
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 123.283
#  valeur du portefeuille 47.24753799999997
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 349
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 124.82
#  valeur du portefeuille 47.99451999999998
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 350
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 124.492
#  valeur du portefeuille 47.83911199999998
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 351
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 122.372
#  valeur du portefeuille 46.81579199999998
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 352
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 122.679
#  valeur du portefeuille 46.96799399999998
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 353
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 122.371
#  valeur du portefeuille 46.82130599999999
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 354
#  delta option 0.998 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 120.76
#  valeur du portefeuille 46.04435999999998
#  delta portefeuille 0.484
# On ne hedge pas à cette période
# En période 355
#  delta option 0.999 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 118.633
#  valeur du portefeuille 45.01563799999998
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 356
#  delta option 0.999 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 119.395
#  valeur du portefeuille 45.38796999999998
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 357
#  delta option 0.999 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 120.986
#  valeur du portefeuille 46.16219599999998
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 358
#  delta option 0.999 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 122.762
#  valeur du portefeuille 47.026331999999975
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 359
#  delta option 0.999 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 123.444
#  valeur du portefeuille 47.36078399999998
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 360
#  delta option 0.999 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 123.442
#  valeur du portefeuille 47.36281199999999
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 361
#  delta option 0.999 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 123.68
#  valeur du portefeuille 47.48147999999999
#  delta portefeuille 0.485
# On ne hedge pas à cette période
# En période 362
#  delta option 1.0 | Var delta 0.0010000000000000009
#  quantité sous-jacent -0.514 | Prix action 123.732
#  valeur du portefeuille 47.50975199999999
#  delta portefeuille 0.486
# On ne hedge pas à cette période
# En période 363
#  delta option 1.0 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 124.758
#  valeur du portefeuille 48.01138799999999
#  delta portefeuille 0.486
# On ne hedge pas à cette période
# En période 364
#  delta option 1.0 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 124.109
#  valeur du portefeuille 47.699974
#  delta portefeuille 0.486
# On ne hedge pas à cette période
# En période 365
#  delta option 1.0 | Var delta 0.0
#  quantité sous-jacent -0.514 | Prix action 122.474
#  valeur du portefeuille 46.908363999999985
#  delta portefeuille 0.486
